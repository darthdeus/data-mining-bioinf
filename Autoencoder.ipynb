# %%
import keras
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import sklearn.datasets as datasets
# Out:
# Using TensorFlow backend.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Input

# %%
import sklearn
import sklearn.decomposition as decomposition
import sklearn.manifold as manifold

# %%
dataset = datasets.load_digits()
X, y = dataset.data, dataset.target

# %%
pca = decomposition.PCA()
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
sums = np.cumsum(pca.explained_variance_ratio_)
plt.plot(range(len(sums)), sums)

# %%
X_vis = manifold.TSNE().fit_transform(X)

# %%
plt.scatter(X_vis[:,0], X_vis[:,1], c=y)

# %%
from matplotlib import animation
from IPython.display import HTML

fig = plt.figure()
ax = fig.add_subplot(111)
d = np.random.rand(20, 2)

def make_frame(i):
    np.subtract(d, 0.1, )
    ax.clear()
    ax.scatter(d[:, 0], d[:, 1])

myanim = animation.FuncAnimation(fig, make_frame, frames=30, interval=20)
HTML(myanim.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
