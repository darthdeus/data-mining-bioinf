# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/rok2016.txt", delimiter="|")
df.head()
# Out:
#         Datum   1 AUD   1 BGN  1 BRL   1 CAD   1 CHF  1 CNY  1 DKK   1 EUR  \
# 0  04.01.2016  17,828  13,814  6,152  17,810  24,796  3,795  3,621  27,020
# 1  05.01.2016  18,038  13,814  6,279  18,042  24,909  3,856  3,622  27,020
# 2  06.01.2016  17,798  13,818  6,233  17,865  24,918  3,845  3,623  27,025
# 3  07.01.2016  17,378  13,820  6,142  17,595  24,857  3,772  3,623  27,030
# 4  08.01.2016  17,438  13,816  6,185  17,632  24,876  3,774  3,622  27,020
#
#     1 GBP  ...    1 PLN  1 RON 100 RUB  1 SEK   1 SGD 100 THB  1 TRY   1 USD  \
# 0  36,609  ...    6,288  5,982  33,904  2,946  17,393  68,566  8,399  24,794
# 1  36,892  ...    6,272  5,969  34,262  2,929  17,648  69,597  8,441  25,145
# 2  36,829  ...    6,231  5,976  33,815  2,927  17,565  69,563  8,361  25,196
# 3  36,272  ...    6,216  5,969  33,053  2,913  17,314  68,541  8,238  24,873
# 4  36,246  ...    6,206  5,969  33,609  2,917  17,310  68,597  8,322  24,873
#
#     1 XDR  1 ZAR
# 0  34,403  1,593
# ...

# %%
data = df[["1 EUR", "1 USD"]].values

# %%
plt.plot(range(len(data)), data[:,1])
plt.show()
